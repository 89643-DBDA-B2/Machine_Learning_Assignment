# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# Linear regression

# %%
df = pd.read_csv('D:/DBDA_Official10/Machine_Learning/Machine_Learning/Assignment/Datasets/delivery_time.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  21 non-null     float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 468.0 bytes

# %%
df.head()
# Out:
#    Delivery Time  Sorting Time
# 0          21.00            10
# 1          13.50             4
# 2          19.75             6
# 3          24.00             9
# 4          29.00            10

# %%
df.isnull().sum()
# Out:
# Delivery Time    0
# Sorting Time     0
# dtype: int64

# %%
df.describe()
# Out:
#        Delivery Time  Sorting Time
# count      21.000000     21.000000
# mean       16.790952      6.190476
# std         5.074901      2.542028
# min         8.000000      2.000000
# 25%        13.500000      4.000000
# 50%        17.830000      6.000000
# 75%        19.750000      8.000000
# max        29.000000     10.000000

# %%
df.cov()
# Out:
#                Delivery Time  Sorting Time
# Delivery Time      25.754619     10.655810
# Sorting Time       10.655810      6.461905

# %%
df.corr()
# Out:
#                Delivery Time  Sorting Time
# Delivery Time       1.000000      0.825997
# Sorting Time        0.825997      1.000000

# %% [markdown]
# EDA Visualization

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
plt.scatter(df['Delivery Time'] , df['Sorting Time'])
plt.xlabel("Delivery Time")
plt.ylabel("Sorting Time")
plt.title("works")
plt.legend()

# %% [markdown]
# Data Cleansing

# %% [markdown]
# Splitting data

# %%
x = df.drop(['Sorting Time'],axis =1)
y = df.drop(['Delivery Time'], axis =1)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state = 123456)

# %% [markdown]
# Generating model

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(x_test)
# Out:
# array([[8.25765302],
#        [3.98434607],
#        [6.19791907],
#        [7.08249361],
#        [5.62956925]])

# %%
y_pred = model.predict(x_train)
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import r2_score

mae = mean_absolute_error(y_train,y_pred)
mse = mean_squared_error(y_train,y_pred)
rmse = root_mean_squared_error(y_train,y_pred)
r2 = r2_score(y_train,y_pred)

print(mae,mse,rmse,r2)
# Out:
# 0.9480874405764785 1.5738930753181588 1.2545489529381302 0.7689698238065088
